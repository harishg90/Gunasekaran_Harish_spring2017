# %%
from pandas import Series, DataFrame
import pandas as pd
import numpy as np
import glob

path = "../Flight data/*_2016.csv"
frame=pd.DataFrame()
df_list=[]

for fname in glob.glob(path):    
    df=pd.read_csv(fname,index_col=None, header=0)
    df_list.append(df)
frame = pd.concat(df_list)
frame.head()
frame=frame.fillna(0)
frame["DEP_HOUR"]=frame["DEP_TIME"].astype(int)
frame["HOUR"]=(frame["DEP_HOUR"]//100)
frame.head()
# Out:
#    AIRLINE_ID  ARR_DELAY_NEW  ARR_TIME  CANCELLED CARRIER  CARRIER_DELAY  \
# 0       20416            0.0    1857.0        0.0      NK            0.0
# 1       20416           13.0    1924.0        0.0      NK            0.0
# 2       20416           50.0    2010.0        0.0      NK            0.0
# 3       20416            3.0    1923.0        0.0      NK            0.0
# 4       20416            4.0    2112.0        0.0      NK            0.0
#
#    DAY_OF_WEEK  DEP_DELAY_NEW  DEP_TIME DEST ...   LATE_AIRCRAFT_DELAY  \
# 0            1            0.0    1524.0  MCO ...                   0.0
# 1            1           19.0    1552.0  MCO ...                   0.0
# 2            1           53.0    1635.0  MCO ...                  50.0
# 3            1            0.0    1539.0  MCO ...                   0.0
# 4            1            0.0    2003.0  FLL ...                   0.0
#
#   NAS_DELAY  ORIGIN  ORIGIN_AIRPORT_ID  ORIGIN_CITY_NAME SECURITY_DELAY  \
# ...

# %%
def f(row):
    if row == "1":
        val="MONDAY"
    elif row == "2":
        val="TUESDAY"
    elif row == "3":
        val="WEDNESDAY"
    elif row == "4":
        val="THURSDAY"
    elif row == "5":
        val="FRIDAY"
    elif row == "6":
        val="SATURDAY"
    else:
        val="SUNDAY"
    return val
frame['weekday_name'] = frame.apply(lambda x:f(str(x['DAY_OF_WEEK'])),axis=1)
frame.head()
# Out:
#    DAY_OF_WEEK  AIRLINE_ID ORIGIN_CITY_NAME          DEST_CITY_NAME  FL_NUM  \
# 0            1       19790      Atlanta, GA            Richmond, VA    2399
# 1            1       19790     Richmond, VA             Atlanta, GA    2399
# 2            1       19790      Atlanta, GA               Omaha, NE    2400
# 3            1       19790        Omaha, NE             Atlanta, GA    2400
# 4            1       19790      Atlanta, GA  Bloomington/Normal, IL    2401
#
#    DEP_TIME  DEP_HOUR  HOUR weekday_name
# 0    1243.0      1243    12       MONDAY
# 1    1501.0      1501    15       MONDAY
# 2    1049.0      1049    10       MONDAY
# 3    1254.0      1254    12       MONDAY
# 4    2121.0      2121    21       MONDAY

# %%
df=DataFrame(frame,columns=["HOUR","weekday_name","ORIGIN_CITY_NAME","FL_NUM"])
offdata=DataFrame(df.groupby(['ORIGIN_CITY_NAME','weekday_name','HOUR'])['FL_NUM'].count())
offdata=offdata.reset_index()

# %%
city=input("text")
weekday=input("text")
offdata=offdata[offdata.ORIGIN_CITY_NAME==city]
offdata=offdata[offdata.weekday_name==weekday]


import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import datetime
import time
#saturated=pd.read_csv("output/melted.csv")
sns.factorplot(x="FL_NUM",y="weekday_name",hue="HOUR",data=offdata,saturation=2,size=10,aspect=1,kind="bar",legend=True)

plt.title('No of Flights',fontsize=15,y=1.08)
plt.xlabel('Weekday')
plt.ylabel('HOURLY FLIGHT TOOK OFF FROM ANY CITY')
ax = plt.gca()
ax.get_xaxis().get_major_formatter().set_scientific(False)
plt.draw()
plt.figtext(1.0, 1.10, 'Date Generated:'+str(datetime.datetime.fromtimestamp(time.time()).strftime('%Y-%m-%d %H:%M:%S')), horizontalalignment='right')

fig1 = plt.gcf()
plt.show()
# Out:
# textAtlanta, GA
# textMONDAY
